# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score, classification_report

# Load the Iris dataset
iris = load_iris()
X = iris.data[:, 2:]  # Selecting petal length and width features only
y = iris.target

# Display dataset
print("Dataset:")
print("Petal Length | Petal Width | Species")
for i in range(len(X)):
    print(f"{X[i][0]:.2f}          {X[i][1]:.2f}          {iris.target_names[y[i]]}")

# Split the dataset into training and testing parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train logistic regression multiclass algorithm using Softmax Regression
log_reg = LogisticRegression(multi_class='multinomial')
log_reg.fit(X_train, y_train)

# Test the logistic regression algorithm on testing dataset
y_pred_log_reg = log_reg.predict(X_test)

# Display results for logistic regression
print("\nResults for Logistic Regression:")
print("Accuracy:", accuracy_score(y_test, y_pred_log_reg))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_log_reg, target_names=iris.target_names))

# Train linear SVM algorithm
linear_svm = LinearSVC(C=1)
linear_svm.fit(X_train, y_train)

# Test the linear SVM algorithm on testing dataset
y_pred_linear_svm = linear_svm.predict(X_test)

# Display results for linear SVM
print("\nResults for Linear SVM:")
print("Accuracy:", accuracy_score(y_test, y_pred_linear_svm))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_linear_svm, target_names=iris.target_names))

# Train soft SVM algorithm
soft_svm = SVC(kernel='linear', C=1)
soft_svm.fit(X_train, y_train)

# Test the soft SVM algorithm on testing dataset
y_pred_soft_svm = soft_svm.predict(X_test)

# Display results for soft SVM
print("\nResults for Soft SVM:")
print("Accuracy:", accuracy_score(y_test, y_pred_soft_svm))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_soft_svm, target_names=iris.target_names))
# Out:
# Dataset:
# Petal Length | Petal Width | Species
# 1.40          0.20          setosa
# 1.40          0.20          setosa
# 1.30          0.20          setosa
# 1.50          0.20          setosa
# 1.40          0.20          setosa
# 1.70          0.40          setosa
# 1.40          0.30          setosa
# 1.50          0.20          setosa
# 1.40          0.20          setosa
# 1.50          0.10          setosa
# 1.50          0.20          setosa
# 1.60          0.20          setosa
# 1.40          0.10          setosa
# 1.10          0.10          setosa
# 1.20          0.20          setosa
# 1.50          0.40          setosa
# 1.30          0.40          setosa
# 1.40          0.30          setosa
# 1.70          0.30          setosa
# 1.50          0.30          setosa
# 1.70          0.20          setosa
# 1.50          0.40          setosa
# 1.00          0.20          setosa
# 1.70          0.50          setosa
# 1.90          0.20          setosa
# 1.60          0.20          setosa
# 1.60          0.40          setosa
# 1.50          0.20          setosa
# 1.40          0.20          setosa
# 1.60          0.20          setosa
# 1.60          0.20          setosa
# 1.50          0.40          setosa
# 1.50          0.10          setosa
# 1.40          0.20          setosa
# 1.50          0.20          setosa
# 1.20          0.20          setosa
# 1.30          0.20          setosa
# 1.40          0.10          setosa
# 1.30          0.20          setosa
# 1.50          0.20          setosa
# 1.30          0.30          setosa
# 1.30          0.30          setosa
# 1.30          0.20          setosa
# 1.60          0.60          setosa
# 1.90          0.40          setosa
# 1.40          0.30          setosa
# 1.60          0.20          setosa
# 1.40          0.20          setosa
# 1.50          0.20          setosa
# 1.40          0.20          setosa
# 4.70          1.40          versicolor
# 4.50          1.50          versicolor
# 4.90          1.50          versicolor
# 4.00          1.30          versicolor
# 4.60          1.50          versicolor
# 4.50          1.30          versicolor
# 4.70          1.60          versicolor
# 3.30          1.00          versicolor
# 4.60          1.30          versicolor
# 3.90          1.40          versicolor
# 3.50          1.00          versicolor
# 4.20          1.50          versicolor
# 4.00          1.00          versicolor
# 4.70          1.40          versicolor
# 3.60          1.30          versicolor
# 4.40          1.40          versicolor
# 4.50          1.50          versicolor
# 4.10          1.00          versicolor
# 4.50          1.50          versicolor
# 3.90          1.10          versicolor
# 4.80          1.80          versicolor
# 4.00          1.30          versicolor
# 4.90          1.50          versicolor
# 4.70          1.20          versicolor
# 4.30          1.30          versicolor
# 4.40          1.40          versicolor
# 4.80          1.40          versicolor
# 5.00          1.70          versicolor
# 4.50          1.50          versicolor
# 3.50          1.00          versicolor
# 3.80          1.10          versicolor
# 3.70          1.00          versicolor
# 3.90          1.20          versicolor
# 5.10          1.60          versicolor
# 4.50          1.50          versicolor
# 4.50          1.60          versicolor
# 4.70          1.50          versicolor
# 4.40          1.30          versicolor
# 4.10          1.30          versicolor
# 4.00          1.30          versicolor
# 4.40          1.20          versicolor
# 4.60          1.40          versicolor
# 4.00          1.20          versicolor
# 3.30          1.00          versicolor
# 4.20          1.30          versicolor
# 4.20          1.20          versicolor
# 4.20          1.30          versicolor
# 4.30          1.30          versicolor
# 3.00          1.10          versicolor
# 4.10          1.30          versicolor
# 6.00          2.50          virginica
# 5.10          1.90          virginica
# 5.90          2.10          virginica
# 5.60          1.80          virginica
# 5.80          2.20          virginica
# 6.60          2.10          virginica
# 4.50          1.70          virginica
# 6.30          1.80          virginica
# 5.80          1.80          virginica
# 6.10          2.50          virginica
# 5.10          2.00          virginica
# 5.30          1.90          virginica
# 5.50          2.10          virginica
# 5.00          2.00          virginica
# 5.10          2.40          virginica
# 5.30          2.30          virginica
# 5.50          1.80          virginica
# 6.70          2.20          virginica
# 6.90          2.30          virginica
# 5.00          1.50          virginica
# 5.70          2.30          virginica
# 4.90          2.00          virginica
# 6.70          2.00          virginica
# 4.90          1.80          virginica
# 5.70          2.10          virginica
# 6.00          1.80          virginica
# 4.80          1.80          virginica
# 4.90          1.80          virginica
# 5.60          2.10          virginica
# 5.80          1.60          virginica
# 6.10          1.90          virginica
# 6.40          2.00          virginica
# 5.60          2.20          virginica
# 5.10          1.50          virginica
# 5.60          1.40          virginica
# 6.10          2.30          virginica
# 5.60          2.40          virginica
# 5.50          1.80          virginica
# 4.80          1.80          virginica
# 5.40          2.10          virginica
# 5.60          2.40          virginica
# 5.10          2.30          virginica
# 5.10          1.90          virginica
# 5.90          2.30          virginica
# 5.70          2.50          virginica
# 5.20          2.30          virginica
# 5.00          1.90          virginica
# 5.20          2.00          virginica
# 5.40          2.30          virginica
# 5.10          1.80          virginica
#
# Results for Logistic Regression:
# Accuracy: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      1.00      1.00         7
#    virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Results for Linear SVM:
# Accuracy: 0.9666666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.88      1.00      0.93         7
#    virginica       1.00      0.90      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
#
# Results for Soft SVM:
# Accuracy: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      1.00      1.00         7
#    virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
# c:\Users\admin\anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
